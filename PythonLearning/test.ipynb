# %%
print(5/3) #1.666
print(5//3) #1 Floor()
print (-(5//-3)) #upside-down-floor for "Ceil() function (alt)" OUTPUT: 2
z = complex(1, 4) #OUTPUT: 1+4j means in maths 1+4i Equation.
print(z)
print (5**3) #125 returns power
print(10.0.is_integer()) #TRUE
print(10.2.is_integer()) #FALSE
print(10).bit_length() #4

x1 = float(2) #2.0
print(x1)

x2 = float(2.0) #2.0
print(x2)

x3 = float("44") #44.0  converted into float datatype
print(x3)

x4 = float(complex(1, 2)) #error
print(x4)
# Out:
# 1.6666666666666667
# 1
# 2
# (1+4j)
# 125
# True
# False
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 9
#       7 print(10.0.is_integer()) #TRUE
#       8 print(10.2.is_integer()) #FALSE
# ----> 9 print(10).bit_length() #4
#      11 x1 = float(2) #2.0
#      12 print(x1)
#
# AttributeError: 'NoneType' object has no attribute 'bit_length'
